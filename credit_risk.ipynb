# %% [markdown]
# <a href="https://colab.research.google.com/github/kittidet2541/credit_risk_analysis/blob/main/credit_risk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install copilot-colab
# Out:
# ERROR: Could not find a version that satisfies the requirement copilot-colab (from versions: none)
# ERROR: No matching distribution found for copilot-colab

# %% [markdown]
# # 1. Understanding the Problem & Data Preparation

# %%
import pandas as pd
import numpy as np

# %%
read_csv = pd.read_csv('/content/drive/MyDrive/credit_risk_dataset.csv')

# %%
read_csv
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22          59000                  RENT              123.0
# 1              21           9600                   OWN                5.0
# 2              25           9600              MORTGAGE                1.0
# 3              23          65500                  RENT                4.0
# 4              24          54400                  RENT                8.0
# ...           ...            ...                   ...                ...
# 32576          57          53000              MORTGAGE                1.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
# 32580          66          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %%
read_csv.shape  # ขนาดของข้อมูล (จำนวนแถวและจำนวนคอลัมน์)
read_csv.columns  # ชื่อคอลัมน์
read_csv.info()  # ตรวจสอบชนิดของข้อมูลและข้อมูลที่สูญหาย
read_csv.describe()  # ค่าสถิติเบื้องต้น เช่น ค่าเฉลี่ย ค่าเบี่ยงเบนมาตรฐาน
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32581 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  32581 non-null  int64
#  1   person_income               32581 non-null  int64
#  2   person_home_ownership       32581 non-null  object
#  3   person_emp_length           31686 non-null  float64
#  4   loan_intent                 32581 non-null  object
#  5   loan_grade                  32581 non-null  object
#  6   loan_amnt                   32581 non-null  int64
#  7   loan_int_rate               29465 non-null  float64
#  8   loan_status                 32581 non-null  int64
#  9   loan_percent_income         32581 non-null  float64
#  10  cb_person_default_on_file   32581 non-null  object
#  11  cb_person_cred_hist_length  32581 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.0+ MB
# ...
